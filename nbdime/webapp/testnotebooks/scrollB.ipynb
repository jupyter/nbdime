# %%
from math import sqrt

def f(x, y):
    r2 = x**2+y**2
    return sqrt(r2)
aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa aaaaaaaaaaaaaaaaaaaa aaaaaaaaaaaaaaaaaaaa aaaaaaa

# %%
l = f(3, 4)
print(l)
# Out:
# 5.0

# %%
def g(z):
    return z**2 + 3.0
g(7)
# Out:
# 52.0
