# %%
None/None
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-14dd8e7a2594> in <module>()
# ----> 1 None/None
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'NoneType'
