# %%
test 3
hello 3
more
text 3
world 3
# Out:
#   File "<ipython-input-7-52370c31eada>", line 1
#     test 3
#          ^
# SyntaxError: invalid syntax

# %%
def f(x, y):
    z = x + y - 9
    return z
f(5, 6)
# Out:
# 2

# %%
123
# Out:
# 123

# %%
# %matplotlib inline
from pylab import *

x = [0, 2, 3]
plot(x, sin(x))
x = [1, 2, 4]
plot(x, tan(x))

print("No conflict at beginning or end here.")
# Out:
# No conflict at beginning or end here.
