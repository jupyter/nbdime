# %%
test
hello
more
text
world
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2ba166c54cbc> in <module>()
#       1 test
# ----> 2 hello
#       3 more
#       4 text
#       5 world
#
# NameError: name 'hello' is not defined

# %%
def f(x, y):
    z = x + y - 1
    return z
f(1, 3)
# Out:
# 3

# %%
123
# Out:
# 123

# %%
# %matplotlib inline
from pylab import *

figure(1)
x = [1, 2, 3]
plot(x, sin(x))
x = [0, 2, 4]
plot(x, cos(x))

print("No conflict at beginning or end here.")
figure(2)
plot([1,2,3], [1,3,2])
# Out:
# No conflict at beginning or end here.
